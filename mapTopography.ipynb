# %%
sc

# %%
from pyspark.sql import Row
import csv
import glob

# %%
path = '.../Photogrammetry/LowerMN_tiles/x-*_y-*.csv'
flist = glob.glob(path)

# %%
#flist[:10]

# %%
dfTile = sqlContext.read.load(flist[0], format='csv', header=False, inferSchema=True)

# %%
dfTile.take(5)
# Out:
# [Row(_c0=0.0, _c1=0.0, _c2=0.0, _c3=0.0, _c4=0.0, _c5=0.0, _c6=0.0, _c7=0.0, _c8=0.0, _c9=0.0, _c10=0.0, _c11=0.0, _c12=0.0, _c13=0.0, _c14=0.0, _c15=0.0, _c16=0.0, _c17=0.0, _c18=0.0, _c19=0.0, _c20=0.0, _c21=0.0, _c22=0.0, _c23=0.0, _c24=0.0, _c25=0.0, _c26=0.0, _c27=0.0, _c28=0.0, _c29=0.0, _c30=0.0, _c31=0.0, _c32=0.0, _c33=0.0, _c34=0.0, _c35=0.0, _c36=0.0, _c37=0.0, _c38=0.0, _c39=0.0, _c40=0.0, _c41=0.0, _c42=0.0, _c43=0.0, _c44=0.0, _c45=0.0, _c46=0.0, _c47=0.0, _c48=0.0, _c49=0.0, _c50=0.0, _c51=0.0, _c52=0.0, _c53=0.0, _c54=0.0, _c55=0.0, _c56=0.0, _c57=0.0, _c58=0.0, _c59=0.0, _c60=0.0, _c61=0.0, _c62=0.0, _c63=0.0, _c64=0.0, _c65=0.0, _c66=0.0, _c67=0.0, _c68=0.0, _c69=0.0, _c70=0.0, _c71=0.0, _c72=0.0, _c73=0.0, _c74=0.0, _c75=0.0, _c76=0.0, _c77=0.0, _c78=0.0, _c79=0.0, _c80=0.0, _c81=0.0, _c82=0.0, _c83=0.0, _c84=0.0, _c85=0.0, _c86=0.0, _c87=0.0, _c88=0.0, _c89=0.0, _c90=0.0, _c91=0.0, _c92=0.0, _c93=0.0, _c94=0.0, _c95=0.0, _c96=0.0, _c97=0.0, _c98=0.0, _c99=0.0, _c1
# ...
